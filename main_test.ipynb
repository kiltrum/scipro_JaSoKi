# %%
from era5vis.crosssection import plot_crosssection

fig = plot_crosssection(
    var="wspd",
    lat=46.5,
    lon=9.0,
    casefile="era5vis-main/data/tmp/test_tmp_with_wind.nc",
    climfile="era5vis-main/data/model_climate/model_clim.nc",
    field="anomaly",  # or "case" or "clim"
    terrainfile="era5vis-main/data/model_terrain/elevaation.nc",
)
fig.show()
# Out:
# /var/folders/r5/2d5m4_zn37d74npwnbfcpcdh0000gn/T/ipykernel_10882/1824908423.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
