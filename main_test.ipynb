# %%
from era5vis.crosssection import plot_crosssection

fig = plot_crosssection(
    casefile="era5vis-main/data/tmp/test_tmp_with_wind.nc",
    var="wspd",
    lat=46.5,
    lon=9.0,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       1 from era5vis.crosssection import plot_crosssection
#       3 fig = plot_crosssection(
#       4     casefile="era5vis-main/data/tmp/test_tmp_with_wind.nc",
#       5     var="wspd",
#       6     lat=46.5,
#       7     lon=9.0,
#       8 )
# ----> 9 fig.show()
#
# AttributeError: 'str' object has no attribute 'show'
